# %%
import pandas as pd

# %%
df = pd.read_csv("wmt20-de-en.tsv", sep="\t", quoting=3, keep_default_na=False)  # quoting=3 is to ignore double quotes

# %%
translations = df.pivot_table(index="text", columns="source", values="translation", aggfunc="first", dropna=True)

# %%
translations
# Out:
# source                                             azonline.de.41749  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...               NaN
# "Der Whistleblower hat uns einen Fahrplan für u...               NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...               NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...               NaN
# "Die Tränen flossen"                                             NaN
# ...                                                              ...
# Ölpreise geben nach Bericht über Waffenstillsta...               NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                 NaN
# Über Cox, die sich für den Verbleib Großbritann...               NaN
# Über die Analyse des Erbguts von 9000 Menschen ...               NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...               NaN
#
# source                                             azonline.de.41866  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...               NaN
# "Der Whistleblower hat uns einen Fahrplan für u...               NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...               NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...               NaN
# "Die Tränen flossen"                                             NaN
# ...                                                              ...
# Ölpreise geben nach Bericht über Waffenstillsta...               NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                 NaN
# Über Cox, die sich für den Verbleib Großbritann...               NaN
# Über die Analyse des Erbguts von 9000 Menschen ...               NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...               NaN
#
# source                                             bild.126537 bild.126691  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...         NaN         NaN
# "Der Whistleblower hat uns einen Fahrplan für u...         NaN         NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...         NaN         NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...         NaN         NaN
# "Die Tränen flossen"                                       NaN         NaN
# ...                                                        ...         ...
# Ölpreise geben nach Bericht über Waffenstillsta...         NaN         NaN
# Öltanker "Stena Impero" verließ iranischen Hafen           NaN         NaN
# Über Cox, die sich für den Verbleib Großbritann...         NaN         NaN
# Über die Analyse des Erbguts von 9000 Menschen ...         NaN         NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...         NaN         NaN
#
# source                                             braunschweiger-zeitung.de.126892  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                              NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                              NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                              NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                              NaN
# "Die Tränen flossen"                                                            NaN
# ...                                                                             ...
# Ölpreise geben nach Bericht über Waffenstillsta...                              NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                                NaN
# Über Cox, die sich für den Verbleib Großbritann...                              NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                              NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                              NaN
#
# source                                             braunschweiger-zeitung.de.126898  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                              NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                              NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                              NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                              NaN
# "Die Tränen flossen"                                                            NaN
# ...                                                                             ...
# Ölpreise geben nach Bericht über Waffenstillsta...                              NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                                NaN
# Über Cox, die sich für den Verbleib Großbritann...                              NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                              NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                              NaN
#
# source                                             braunschweiger-zeitung.de.126957  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                              NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                              NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                              NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                              NaN
# "Die Tränen flossen"                                                            NaN
# ...                                                                             ...
# Ölpreise geben nach Bericht über Waffenstillsta...                              NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                                NaN
# Über Cox, die sich für den Verbleib Großbritann...                              NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                              NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                              NaN
#
# source                                             derstandart.at.346170  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                   NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                   NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                   NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                   NaN
# "Die Tränen flossen"                                                 NaN
# ...                                                                  ...
# Ölpreise geben nach Bericht über Waffenstillsta...                   NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                     NaN
# Über Cox, die sich für den Verbleib Großbritann...                   NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                   NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                   NaN
#
# source                                             derstandart.at.346183  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                   NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                   NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                   NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                   NaN
# "Die Tränen flossen"                                                 NaN
# ...                                                                  ...
# Ölpreise geben nach Bericht über Waffenstillsta...                   NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                     NaN
# Über Cox, die sich für den Verbleib Großbritann...                   NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                   NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                   NaN
#
# source                                             dw.97318  ...  \
# text                                                         ...
# "Absolut verwerflich": Rachel Johnson entsetzt ...      NaN  ...
# "Der Whistleblower hat uns einen Fahrplan für u...      NaN  ...
# "Die Krabben kommen!" Mit diesem Ruf startete a...      NaN  ...
# "Die Tests der Anbieter erfolgen jedoch nach an...      NaN  ...
# "Die Tränen flossen"                                    NaN  ...
# ...                                                     ...  ...
# Ölpreise geben nach Bericht über Waffenstillsta...      NaN  ...
# Öltanker "Stena Impero" verließ iranischen Hafen        NaN  ...
# Über Cox, die sich für den Verbleib Großbritann...      NaN  ...
# Über die Analyse des Erbguts von 9000 Menschen ...      NaN  ...
# Übergewicht, Rauchen und ungesunde Ernährung zä...      NaN  ...
#
# source                                                                   wiesbadener-kurier.de.310619  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                                                NaN
# "Der Whistleblower hat uns einen Fahrplan für u...                                                NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...                                                NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...  "However, the tests of the providers are carri...
# "Die Tränen flossen"                                                                              NaN
# ...                                                                                               ...
# Ölpreise geben nach Bericht über Waffenstillsta...                                                NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                                                  NaN
# Über Cox, die sich für den Verbleib Großbritann...                                                NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                                                NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                                                NaN
#
# source                                                                                   wn.de.623840  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...                                                NaN
# "Der Whistleblower hat uns einen Fahrplan für u...  "The whistleblower has given us a roadmap for ...
# "Die Krabben kommen!" Mit diesem Ruf startete a...                                                NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...                                                NaN
# "Die Tränen flossen"                                                                              NaN
# ...                                                                                               ...
# Ölpreise geben nach Bericht über Waffenstillsta...                                                NaN
# Öltanker "Stena Impero" verließ iranischen Hafen                                                  NaN
# Über Cox, die sich für den Verbleib Großbritann...                                                NaN
# Über die Analyse des Erbguts von 9000 Menschen ...                                                NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...                                                NaN
#
# source                                             yahoo-de.127726  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...             NaN
# "Der Whistleblower hat uns einen Fahrplan für u...             NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...             NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...             NaN
# "Die Tränen flossen"                                           NaN
# ...                                                            ...
# Ölpreise geben nach Bericht über Waffenstillsta...             NaN
# Öltanker "Stena Impero" verließ iranischen Hafen               NaN
# Über Cox, die sich für den Verbleib Großbritann...             NaN
# Über die Analyse des Erbguts von 9000 Menschen ...             NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...             NaN
#
# source                                             yahoo-de.127730  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...             NaN
# "Der Whistleblower hat uns einen Fahrplan für u...             NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...             NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...             NaN
# "Die Tränen flossen"                                           NaN
# ...                                                            ...
# Ölpreise geben nach Bericht über Waffenstillsta...             NaN
# Öltanker "Stena Impero" verließ iranischen Hafen               NaN
# Über Cox, die sich für den Verbleib Großbritann...             NaN
# Über die Analyse des Erbguts von 9000 Menschen ...             NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...             NaN
#
# source                                             yahoo-de.127754  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...             NaN
# "Der Whistleblower hat uns einen Fahrplan für u...             NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...             NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...             NaN
# "Die Tränen flossen"                                           NaN
# ...                                                            ...
# Ölpreise geben nach Bericht über Waffenstillsta...             NaN
# Öltanker "Stena Impero" verließ iranischen Hafen               NaN
# Über Cox, die sich für den Verbleib Großbritann...             NaN
# Über die Analyse des Erbguts von 9000 Menschen ...             NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...             NaN
#
# source                                             yahoo-de.127759  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...             NaN
# "Der Whistleblower hat uns einen Fahrplan für u...             NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...             NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...             NaN
# "Die Tränen flossen"                                           NaN
# ...                                                            ...
# Ölpreise geben nach Bericht über Waffenstillsta...             NaN
# Öltanker "Stena Impero" verließ iranischen Hafen               NaN
# Über Cox, die sich für den Verbleib Großbritann...             NaN
# Über die Analyse des Erbguts von 9000 Menschen ...             NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...             NaN
#
# source                                             yahoo-de.127774 zeit.64402  \
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...             NaN        NaN
# "Der Whistleblower hat uns einen Fahrplan für u...             NaN        NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...             NaN        NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...             NaN        NaN
# "Die Tränen flossen"                                           NaN        NaN
# ...                                                            ...        ...
# Ölpreise geben nach Bericht über Waffenstillsta...             NaN        NaN
# Öltanker "Stena Impero" verließ iranischen Hafen               NaN        NaN
# Über Cox, die sich für den Verbleib Großbritann...             NaN        NaN
# Über die Analyse des Erbguts von 9000 Menschen ...             NaN        NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...             NaN        NaN
#
# source                                             zeit.64417 zeit.64420
# text
# "Absolut verwerflich": Rachel Johnson entsetzt ...        NaN        NaN
# "Der Whistleblower hat uns einen Fahrplan für u...        NaN        NaN
# "Die Krabben kommen!" Mit diesem Ruf startete a...        NaN        NaN
# "Die Tests der Anbieter erfolgen jedoch nach an...        NaN        NaN
# "Die Tränen flossen"                                      NaN        NaN
# ...                                                       ...        ...
# Ölpreise geben nach Bericht über Waffenstillsta...        NaN        NaN
# Öltanker "Stena Impero" verließ iranischen Hafen          NaN        NaN
# Über Cox, die sich für den Verbleib Großbritann...        NaN        NaN
# Über die Analyse des Erbguts von 9000 Menschen ...        NaN        NaN
# Übergewicht, Rauchen und ungesunde Ernährung zä...        NaN        NaN
#
# [785 rows x 118 columns]
